# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import os
from pprint import pprint
import json

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
# Store filepath in a variable
city_csv = "../output_data/cities.csv"

# %%
# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
city_df = pd.read_csv(city_csv, encoding="ISO-8859-1")
city_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Punta Arenas -53.1500  -70.9167     46.40        57           0
# 1        Castro -24.7911  -50.0119     68.81        56          29
# 2         Yumen  40.2833   97.2000     61.77        14          87
# 3    Kaitangata -46.2817  169.8464     53.01        83         100
# 4   Kloulklubed   7.0419  134.2556     77.00        94          40
#
#    Wind Speed        Date
# 0        8.05  1619028968
# 1        7.49  1619029144
# 2        7.38  1619029144
# 3        1.99  1619029144
# 4        3.83  1619029145

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
## skipping this step ##

# %%
## skipping this step ##

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %% [markdown]
# Narrow down the DataFrame to find your ideal weather condition. For example:
#   * A max temperature lower than 80 degrees but higher than 70.
#   * Wind speed less than 10 mph.
#   * Zero cloudiness.
#   * Drop any rows that don't contain all three conditions. You want to be sure the weather is ideal.

# %%
# Filter to max temp between 70 and 80 degrees
mintemp = city_df.loc[city_df["Max Temp"] > 70]
temprange = mintemp.loc[mintemp["Max Temp"] < 80]
addwind = temprange.loc[temprange["Wind Speed"] < 10] 
perfect = addwind.loc[addwind["Cloudiness"] == 0] 
perfect.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 100    Phalodi  27.1333   72.3667     77.31        35           0        8.79
# 180  Hong Kong  22.2855  114.1577     73.99        83           0        6.13
# 244  Clearlake  38.9582 -122.6264     72.00        39           0        1.99
#
#            Date
# 100  1619029179
# 180  1619029210
# 244  1619029234

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %% [markdown]
# * Using Google Places API to find the first hotel for each city located within 5000 meters of your coordinates.

# %%
# Target city
target_city = (perfect['City'])

# Build the endpoint URL
target_url = f"https://maps.googleapis.com/maps/api/geocode/json?address={target_city}&key={g_key}"
base_url = "https://maps.googleapis.com/maps/api/geocode/json?address="

# %%
# create variables to hold the data
city = []
lat = []
lng = []
name = []

# Loop through the list of cities and perform a request for data on each
for city in target_city:
    response = requests.get(base_url + city +"&key=" + g_key)
    geo_data = response.json()
    lat.append(geo_data["results"][0]["geometry"]["location"]["lat"])
    lng.append(geo_data["results"][0]["geometry"]["location"]["lng"])
    name.append(geo_data["results"][0]["address_components"][0]["long_name"])

# %%
# Create DataFrame
city_stats = pd.DataFrame({
    'City': name,
    'Lat': lat,
    'Lng': lng
})
city_stats
# Out:
#         City        Lat         Lng
# 0    Phalodi  27.131235   72.358928
# 1  Hong Kong  22.319304  114.169361
# 2  Clearlake  38.958231 -122.626373

# %%
Latitude = (city_stats['Lat']).astype(str)
Longitude = (city_stats['Lng']).astype(str)
Coord = (Latitude + ", " + Longitude)
city_stats['Coordinates'] = Coord
city_stats.head()
# Out:
#         City        Lat         Lng               Coordinates
# 0    Phalodi  27.131235   72.358928    27.1312346, 72.3589284
# 1  Hong Kong  22.319304  114.169361   22.3193039, 114.1693611
# 2  Clearlake  38.958231 -122.626373  38.9582307, -122.6263728

# %%
# geocoordinates
target_coordinates = "27.131235, 72.358928"
target_radius = 5000
target_type = "hotel"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": g_key
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
# convert response to json
places_data = response.json()

# Print the json (pretty printed)
pprint(places_data)
# Out:
# {'html_attributions': [],
#  'next_page_token': 'ATtYBwL6leqvRS1CBHZoDsrK-XF2zdDbmGJ6zCYlQcrhm5RQAwbup4PQa7WardMrdf3Aelxyb6qWcT2GbX0I9nwe1dRfmGHrw25gFVqNHZTs8JtfoIkkE-K2qN8Z2iIpeYM3lA0iTrwgDmW3Po1UfxxgDDVS7dk7TXi5PiJXj-NUasoWJP9Kqe33CMspWsqJ5TNBFJBgCdeF57OG_16ddTAFMDXdcIqvyRUsYuGuOG2NaWrjBX9Tuvjqo27dWwx3U2BD2fJVJzs3CPiImWwwEr1Z8FY4iWM2MCZgt-qzdOosXjY8RqwcxEztp3QcXwoitcGoKc2HtKBtWweiT4HLAZP7WyOm2Dr3MK33iZGJ2WcRMpgsYqqC6rO2-QPR75Mw9rX7uUiuTsXTphiHtKlkKWNdN-oZF8iMH2ooKCqIw_EbdcT6LfM6uT9y_Q',
#  'results': [{'geometry': {'location': {'lat': 27.1312346, 'lng': 72.3589284},
#                            'viewport': {'northeast': {'lat': 27.15890598635625,
#                                                       'lng': 72.39518161558688},
#                                         'southwest': {'lat': 27.08910049036041,
#                                                       'lng': 72.33051008700252}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png',
#               'name': 'Phalodi',
#               'photos': [{'height': 1440,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/100799211306984321044">Priyanka '
#                                                 'Bishnoi</a>'],
#                           'photo_reference': 'ATtYBwKl4xu1NABypp8Aonycpp9plP7gTa4gU3dFvD9pllgDsyhorrrupQZIbqUeO9n4HqNagRyfx_6wRzioz1eGxRaGLX_eysQ82ZC6BEfqYJQ13nCCKJ8hbpsOb1Vid219sBH8AzMsZxyzvljNNHW4SolV1wWZ4UdaI66JLHiHvwnnbHw',
#                           'width': 1080}],
#               'place_id': 'ChIJ9Rzr-ObqQDkRgsoNH7SYtw0',
#               'reference': 'ChIJ9Rzr-ObqQDkRgsoNH7SYtw0',
#               'scope': 'GOOGLE',
#               'types': ['locality', 'political'],
#               'vicinity': 'Phalodi'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 27.1269558,
#                                         'lng': 72.38146119999999},
#                            'viewport': {'northeast': {'lat': 27.1283154802915,
#                                                       'lng': 72.38293078029149},
#                                         'southwest': {'lat': 27.1256175197085,
#                                                       'lng': 72.38023281970848}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'name': 'HOTEL NEW GOLDEN PALACE , PHALODI',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 445,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/104912346413546388027">HOTEL '
#                                                 'NEW GOLDEN PALACE , '
#                                                 'PHALODI</a>'],
#                           'photo_reference': 'ATtYBwIfF94entBFuD5oOkhjUR0vPD4fxiBCdQ74GyK4w4bRskwc9u4eyD2clmsi8Jhe4-F0u8CcikxEtG8YLd3HrQcItkaElSGYhMWhp1WTePcj2sH_A7DVrpEzjaHHvYkONv2k4BeK3_rElYbGhLmv5e5TnpeFihByM2D_yw4YUpbA1ljN',
#                           'width': 700}],
#               'place_id': 'ChIJw6pqDvrqQDkRhewzYnln78M',
#               'plus_code': {'compound_code': '49GJ+QH Phalodi, Rajasthan, '
#                                              'India',
#                             'global_code': '7JVJ49GJ+QH'},
#               'rating': 3.8,
#               'reference': 'ChIJw6pqDvrqQDkRhewzYnln78M',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 826,
#               'vicinity': 'nagaur road,phalodi,dist. jodhpur(raj.), Phalodi'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 27.1306943, 'lng': 72.3684561},
#                            'viewport': {'northeast': {'lat': 27.1321042802915,
#                                                       'lng': 72.36983093029151},
#                                         'southwest': {'lat': 27.12940631970849,
#                                                       'lng': 72.3671329697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'name': 'Readymoney Sales & Services',
#               'opening_hours': {'open_now': False},
#               'place_id': 'ChIJuyn8OeXqQDkRHJ8ngqQeW4I',
#               'plus_code': {'compound_code': '49J9+79 Phalodi, Rajasthan, '
#                                              'India',
#                             'global_code': '7JVJ49J9+79'},
#               'rating': 5,
#               'reference': 'ChIJuyn8OeXqQDkRHJ8ngqQeW4I',
#               'scope': 'GOOGLE',
#               'types': ['point_of_interest', 'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': 'Kamala Bhavan Road, Bhaiya Nadi, Phalodi'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 27.1276114, 'lng': 72.3687479},
#                            'viewport': {'northeast': {'lat': 27.1289192802915,
#                                                       'lng': 72.3700688302915},
#                                         'southwest': {'lat': 27.1262213197085,
#                                                       'lng': 72.3673708697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#               'name': 'CYBERTECH Group of Computer Education',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 469,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108165699297445580284">CYBERTECH '
#                                                 'Group of Computer '
#                                                 'Education</a>'],
#                           'photo_reference': 'ATtYBwKnR0-SwLkQVKNVdlUPrqevTq7iUIgmmaUihdfVR7EBiOyf-P4Ti0ndMWO3-Uv8KJYNE5A2BFIp0PQgOkQEu_A26nBnblwnlB3gnMNj8VhqIvF1sWluzoiYSd3oIZ6iZjl0r2cS3QI-bHEbxSX0iGCzEstP_QKCcpDe7xcSDz95HSuo',
#                           'width': 960}],
#               'place_id': 'ChIJcwxWpu9DajkRPioegw8GQkc',
#               'plus_code': {'compound_code': '49H9+2F Phalodi, Rajasthan, '
#                                              'India',
#                             'global_code': '7JVJ49H9+2F'},
#               'rating': 4.5,
#               'reference': 'ChIJcwxWpu9DajkRPioegw8GQkc',
#               'scope': 'GOOGLE',
#               'types': ['point_of_interest', 'establishment'],
#               'user_ratings_total': 37,
#               'vicinity': 'behind Sr Sec School, Laxmipura, Dholabala Harijan '
#                           'Basti, Phalodi'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 27.131235,
#                                         'lng': 72.35892799999999},
#                            'viewport': {'northeast': {'lat': 27.1326641302915,
#                                                       'lng': 72.3602095302915},
#                                         'southwest': {'lat': 27.1299661697085,
#                                                       'lng': 72.35751156970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'name': 'Mahindra First Choice Services - 4 Wheeler- M S MOTORS',
#               'place_id': 'ChIJvecdtO3qQDkRgRsboZAM1aU',
#               'rating': 3.5,
#               'reference': 'ChIJvecdtO3qQDkRgRsboZAM1aU',
#               'scope': 'GOOGLE',
#               'types': ['point_of_interest', 'establishment'],
#               'user_ratings_total': 8,
#               'vicinity': 'AIKA CIRCLE, STATE HIGHWAY 28 PHALODI JODHPUR, '
#                           'JODHPUR'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 27.1312346, 'lng': 72.3589284},
#                            'viewport': {'northeast': {'lat': 27.13266393029149,
#                                                       'lng': 72.3602097302915},
#                                         'southwest': {'lat': 27.12996596970849,
#                                                       'lng': 72.3575117697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'name': 'Saras dairy',
#               'place_id': 'ChIJ--YdtO3qQDkR5XtotUdVdeQ',
#               'rating': 5,
#               'reference': 'ChIJ--YdtO3qQDkR5XtotUdVdeQ',
#               'scope': 'GOOGLE',
#               'types': ['food', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': 'Industrial Area , Jodhpur, Phalodi'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 27.1312346, 'lng': 72.3589284},
#                            'viewport': {'northeast': {'lat': 27.13266393029149,
#                                                       'lng': 72.3602097302915},
#                                         'southwest': {'lat': 27.12996596970849,
#                                                       'lng': 72.3575117697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#               'name': 'Electricity Board',
#               'place_id': 'ChIJD7aE3_vqQDkRcIqcgI3rjPo',
#               'rating': 5,
#               'reference': 'ChIJD7aE3_vqQDkRcIqcgI3rjPo',
#               'scope': 'GOOGLE',
#               'types': ['point_of_interest', 'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': 'PWD ke samne, Phalodi'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 27.131235,
#                                         'lng': 72.35892799999999},
#                            'viewport': {'northeast': {'lat': 27.1326641302915,
#                                                       'lng': 72.3602095302915},
#                                         'southwest': {'lat': 27.1299661697085,
#                                                       'lng': 72.35751156970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'name': 'Akash Ganga Courier',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 300,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/109987373317197864516">Akash '
#                                                 'Ganga Courier</a>'],
#                           'photo_reference': 'ATtYBwKG9rTu2tY2iqD1A9h6UYqP2ZCaoenbJIITVf7Fs4H6LTZEseYF5ryYjQjpyp4Tv1lVJsojOnEh5beAubBYRX2W_Q-THDWmCU7G5c8qUKw0zdQLah_thjDrfzBhYVLZ15y1uzJoSyOFhUm8P4LLH0-6rjVzhInnn3DWIMVA132Y2L7D',
#                           'width': 800}],
#               'place_id': 'ChIJvecdtO3qQDkR1xUhs7Phly0',
#               'rating': 5,
#               'reference': 'ChIJvecdtO3qQDkR1xUhs7Phly0',
#               'scope': 'GOOGLE',
#               'types': ['point_of_interest', 'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': '#12, inside, Roadway, new Bus Stop,, Phalodi'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 27.1312346, 'lng': 72.3589284},
#                            'viewport': {'northeast': {'lat': 27.13266393029149,
#                                                       'lng': 72.3602097302915},
#                                         'southwest': {'lat': 27.12996596970849,
#                                                       'lng': 72.3575117697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#               'name': 'Gps Khichdo Ki Dhani Padiyal',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 4160,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/110188950525984978080">Ladhu '
#                                                 'Singh</a>'],
#                           'photo_reference': 'ATtYBwJu_IsKK64jkR58O7HzK6V-vBFmsG3KFab2rbLcvhvTVAxOXyfK6QgWLDnE1j0-a-ldM_n7p9rVOqnNWOnFmfokx5gIBkJqDst1Xw4luI0UssI8dgwpTAL-y-NVAYHzmbd4xy3rB-cew9Vn6b5AuWv69SjDljse2JgRhDdp8xZSW0jf',
#                           'width': 3120}],
#               'place_id': 'ChIJ--YdtO3qQDkRajblFEuqVeA',
#               'rating': 3.8,
#               'reference': 'ChIJ--YdtO3qQDkRajblFEuqVeA',
#               'scope': 'GOOGLE',
#               'types': ['school', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 8,
#               'vicinity': 'Padiyal, Phalodi'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 27.1312346, 'lng': 72.3589284},
#                            'viewport': {'northeast': {'lat': 27.13266393029149,
#                                                       'lng': 72.3602097302915},
#                                         'southwest': {'lat': 27.12996596970849,
#                                                       'lng': 72.3575117697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#               'name': 'Government Primary School Khichan',
#               'place_id': 'ChIJ--YdtO3qQDkRkhJdJ2fLpb0',
#               'reference': 'ChIJ--YdtO3qQDkRkhJdJ2fLpb0',
#               'scope': 'GOOGLE',
#               'types': ['primary_school',
#                         'school',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': 'Phalodi, Jodhpur, Khichan'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 27.1312346, 'lng': 72.3589284},
#                            'viewport': {'northeast': {'lat': 27.13266393029149,
#                                                       'lng': 72.3602097302915},
#                                         'southwest': {'lat': 27.12996596970849,
#                                                       'lng': 72.3575117697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#               'name': 'Government Primary School Sri Lachhamannagar',
#               'place_id': 'ChIJ--YdtO3qQDkRMgZMwlHk30M',
#               'rating': 3,
#               'reference': 'ChIJ--YdtO3qQDkRMgZMwlHk30M',
#               'scope': 'GOOGLE',
#               'types': ['primary_school',
#                         'school',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 2,
#               'vicinity': 'Sri Lachhamannagar, Phalodi'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 27.1312346, 'lng': 72.3589284},
#                            'viewport': {'northeast': {'lat': 27.13266393029149,
#                                                       'lng': 72.3602097302915},
#                                         'southwest': {'lat': 27.12996596970849,
#                                                       'lng': 72.3575117697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#               'name': 'Government Primary School',
#               'place_id': 'ChIJ--YdtO3qQDkR41_yMeVh844',
#               'rating': 4,
#               'reference': 'ChIJ--YdtO3qQDkR41_yMeVh844',
#               'scope': 'GOOGLE',
#               'types': ['school', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': 'PALINA, Phalodi'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 27.1312346, 'lng': 72.3589284},
#                            'viewport': {'northeast': {'lat': 27.13266393029149,
#                                                       'lng': 72.3602097302915},
#                                         'southwest': {'lat': 27.12996596970849,
#                                                       'lng': 72.3575117697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#               'name': 'Government Upper Primary School jodhon Ki Dhani',
#               'place_id': 'ChIJ--YdtO3qQDkREYPyTEgl48U',
#               'reference': 'ChIJ--YdtO3qQDkREYPyTEgl48U',
#               'scope': 'GOOGLE',
#               'types': ['primary_school',
#                         'school',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': 'Sri Ramnagar , Jodhpur, Phalodi'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 27.1312346, 'lng': 72.3589284},
#                            'viewport': {'northeast': {'lat': 27.13266393029149,
#                                                       'lng': 72.3602097302915},
#                                         'southwest': {'lat': 27.12996596970849,
#                                                       'lng': 72.3575117697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#               'name': 'Govt. P.S.Madrupaniyon Ki Dhani',
#               'place_id': 'ChIJ--YdtO3qQDkRb0Fb3EoarII',
#               'rating': 5,
#               'reference': 'ChIJ--YdtO3qQDkRb0Fb3EoarII',
#               'scope': 'GOOGLE',
#               'types': ['school', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': 'Daya Kor, Jodhpur, Phalodi'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 27.1312346, 'lng': 72.3589284},
#                            'viewport': {'northeast': {'lat': 27.13266393029149,
#                                                       'lng': 72.3602097302915},
#                                         'southwest': {'lat': 27.12996596970849,
#                                                       'lng': 72.3575117697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#               'name': 'Government Primary School Siwro Ki Dhani',
#               'place_id': 'ChIJ--YdtO3qQDkRgSIklrJ3OcI',
#               'reference': 'ChIJ--YdtO3qQDkRgSIklrJ3OcI',
#               'scope': 'GOOGLE',
#               'types': ['primary_school',
#                         'school',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': 'Denok, Phalodi, jodhpur'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 27.1312346, 'lng': 72.3589284},
#                            'viewport': {'northeast': {'lat': 27.13266393029149,
#                                                       'lng': 72.3602097302915},
#                                         'southwest': {'lat': 27.12996596970849,
#                                                       'lng': 72.3575117697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#               'name': 'GPS Cholaviya Nada',
#               'place_id': 'ChIJ--YdtO3qQDkRfOV60q8Hldw',
#               'reference': 'ChIJ--YdtO3qQDkRfOV60q8Hldw',
#               'scope': 'GOOGLE',
#               'types': ['school', 'point_of_interest', 'establishment'],
#               'vicinity': 'Ramdev Nagar,Jodhpur, Phalodi'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 27.1312346, 'lng': 72.3589284},
#                            'viewport': {'northeast': {'lat': 27.13266393029149,
#                                                       'lng': 72.3602097302915},
#                                         'southwest': {'lat': 27.12996596970849,
#                                                       'lng': 72.3575117697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#               'name': 'Govt.Primary School Manak Chowk',
#               'place_id': 'ChIJ--YdtO3qQDkRDa5llTm4MRo',
#               'reference': 'ChIJ--YdtO3qQDkRDa5llTm4MRo',
#               'scope': 'GOOGLE',
#               'types': ['primary_school',
#                         'school',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': 'Manak Chowk , Phalodi City, Jodhpur'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 27.1312346, 'lng': 72.3589284},
#                            'viewport': {'northeast': {'lat': 27.13266393029149,
#                                                       'lng': 72.3602097302915},
#                                         'southwest': {'lat': 27.12996596970849,
#                                                       'lng': 72.3575117697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#               'name': 'Government Primary School Deepawat Nagar',
#               'place_id': 'ChIJ--YdtO3qQDkRqPmEjoWWQvk',
#               'rating': 1,
#               'reference': 'ChIJ--YdtO3qQDkRqPmEjoWWQvk',
#               'scope': 'GOOGLE',
#               'types': ['primary_school',
#                         'school',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': 'Phalodi, Jodhpur, Bagdawat Nagar'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 27.1312346, 'lng': 72.3589284},
#                            'viewport': {'northeast': {'lat': 27.13266393029149,
#                                                       'lng': 72.3602097302915},
#                                         'southwest': {'lat': 27.12996596970849,
#                                                       'lng': 72.3575117697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#               'name': 'Government Senior Secondary School Boys,phalodi',
#               'place_id': 'ChIJ--YdtO3qQDkRUlWl1OJ4sxA',
#               'rating': 3,
#               'reference': 'ChIJ--YdtO3qQDkRUlWl1OJ4sxA',
#               'scope': 'GOOGLE',
#               'types': ['secondary_school',
#                         'school',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 2,
#               'vicinity': 'Phalodi'},
#              {'geometry': {'location': {'lat': 27.130966, 'lng': 72.3651502},
#                            'viewport': {'northeast': {'lat': 27.13519714828932,
#                                                       'lng': 72.36966870362282},
#                                         'southwest': {'lat': 27.12688226265824,
#                                                       'lng': 72.35876736393821}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png',
#               'name': 'Bhaiya Nadi',
#               'photos': [{'height': 384,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/115085495632480301923">Vardhan '
#                                                 'Jain</a>'],
#                           'photo_reference': 'ATtYBwKJpWCWJyLSfaDrlayKb_oqcmFehdl4CxEUx4MB74iwApfpd_axYFt0l4Yglg8zcBo4316q0iXxI3-2COqeMoFPFrCqEyGo9M0s5GOffIySOur0DQlWepj-Lr5QGhY0GZHgVNqp260IVVm3eZrND_SLcVqPSCn3DVE9NNCR6aI_FVBj',
#                           'width': 480}],
#               'place_id': 'ChIJ0UDqB_DqQDkRPv1HKHuA7K0',
#               'reference': 'ChIJ0UDqB_DqQDkRPv1HKHuA7K0',
#               'scope': 'GOOGLE',
#               'types': ['sublocality_level_1', 'sublocality', 'political'],
#               'vicinity': 'Bhaiya Nadi'}],
#  'status': 'OK'}

# %%
# Print the name and address of the first restaurant that appears
print(places_data["results"][0]["name"])
print(places_data["results"][1]["name"])
# Out:
# Phalodi
# HOTEL NEW GOLDEN PALACE , PHALODI

# %%
## skipping this step ##
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
## skipping this step ##
# Add marker layer ontop of heat map


# Display figure
